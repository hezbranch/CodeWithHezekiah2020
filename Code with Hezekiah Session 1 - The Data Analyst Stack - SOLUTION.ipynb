# %% [markdown]
# # Code with Hezekiah
#
# Session 1
#
# The Data Analyst Stack
#
# January 25, 2020
#
# Created by Hezekiah Branch, https://www.linkedin.com/in/hezekiahbranch/

# %% [markdown]
# ## Background

# %% [markdown]
# **Here's an opportunity to get your feet wet with Python!!**
#
# Today we will be working with United States data from the YouTube for Developers API!
#
# Shoutout to @datasnaek for collecting this data with their source code.
#
# Here's a little bit about that process from the user themself:
#
# **Context**
#
# YouTube (the world-famous video sharing website) maintains a list of the top trending videos on the platform. According to Variety magazine, “To determine the year’s top-trending videos, YouTube uses a combination of factors including measuring users interactions (number of views, shares, comments and likes). Note that they’re not the most-viewed videos overall for the calendar year”. Top performers on the YouTube trending list are music videos (such as the famously virile “Gangam Style”), celebrity and/or reality TV performances, and the random dude-with-a-camera viral videos that YouTube is well-known for.
#
# This dataset is a daily record of the top trending YouTube videos.
#
# Note that this dataset is a structurally improved version of this dataset.***
#
# Source: https://www.kaggle.com/datasnaek/youtube-new

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Collection

# %% [markdown]
# Read the data file named "USvideos.csv" into a pandas dataframe. Save the dataframe as "youtube_data".

# %%
youtube_data = pd.read_csv("USvideos.csv")

# %%
youtube_data.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Display all of the columns in the dataset by writing a Python command below:

# %%
youtube_data.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %% [markdown]
# Take a look at the information for the pandas data structure itself and its attributes.

# %%
youtube_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40949 entries, 38547 to 14335
# Data columns (total 6 columns):
# video_id         40949 non-null object
# title            40949 non-null object
# trending_date    40949 non-null object
# views            40949 non-null int64
# likes            40949 non-null int64
# dislikes         40949 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 3.4+ MB

# %% [markdown]
# Generate a summary of statistics of the YouTube dataset. Save the output as "ytstats".

# %%
ytstats = youtube_data.describe()
ytstats
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %% [markdown]
# As you may have guessed, this data set contains many columns that aren't really useful to what we want to do for this exercise.
#
# ---------------------------------------------------------------------------------------------------------------------
# In order to complete the next steps of this workshop, you will need to extract the following columns:
#
# * video_id - this unique ID will allow us to avoid duplicate entries of a single video
#
# * title - name of the video that was uploaded
#
# * trending_date - column is useful if we want to look at trends over time
#
# * views - gives us a sense of viewer engagement
#
# * likes - you have the power to determine how you want to interpret this metric
#
# * dislikes - this may or may not be a quality metric and it's entirely up to you

# %% [markdown]
# Write your pandas command to extract the columns:

# %%
youtube_data = youtube_data.loc[:, ['video_id', 'title', 'trending_date', 'views', 'likes', 'dislikes']]

# %% [markdown]
# As we continue, think about what other information you would have wanted from this data set!

# %% [markdown]
# Sort your new data set by the number of views in descending order.

# %%
youtube_data = youtube_data.sort_values(by='views', ascending = False)
youtube_data
# Out:
#           video_id                                              title  \
# 38547  VYOjWnS4cMY  Childish Gambino - This Is America (Official V...
# 38345  VYOjWnS4cMY  Childish Gambino - This Is America (Official V...
# 38146  VYOjWnS4cMY  Childish Gambino - This Is America (Official V...
# 37935  VYOjWnS4cMY  Childish Gambino - This Is America (Official V...
# 37730  VYOjWnS4cMY  Childish Gambino - This Is America (Official V...
# ...            ...                                                ...
# 546    -JVITToppE0      Coach Taggart Monday Presser Ahead of Arizona
# 14531  dQMZLXaa1L8                                      Artwork Forge
# 14782  y6KYFcta4SE   1 dead, others injured after Ky. school shooting
# 14563  y6KYFcta4SE   1 dead, others injured after Ky. school shooting
# 14335  y6KYFcta4SE   1 dead, others injured after Ky. school shooting
#
#       trending_date      views    likes  dislikes
# 38547      18.02.06  225211923  5023450    343541
# 38345      18.01.06  220490543  4962403    338105
# 38146      18.31.05  217750076  4934188    335462
# 37935      18.30.05  210338856  4836448    326902
# 37730      18.29.05  205643016  4776680    321493
# ...             ...        ...      ...       ...
# 546        17.16.11        687       10         2
# 14531      18.27.01        658        1         0
# 14782      18.28.01        559        9         0
# 14563      18.27.01        554        9         0
# 14335      18.26.01        549        9         0
#
# [40949 rows x 6 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# If you look closely at the table, you can see that our search for the most popular YouTube trends is simply showing a bunch of duplicate entries.
#
# How should we proceed?

# %% [markdown]
# Well, here's how. Choose the duplicate with the highest views and do that for each entry from the table.
#
# **IMPORTANT**
#
# Q: What column should you rely on to complete this function?
#
# A: video_id (check above in the column descriptions for why)
#
# For right now, we aren't concerned with the date and time, only the highest views. So we can ignore the multiple entries and simply choose the highest viewed video for each unique video ID.

# %% [markdown]
# Write your code below to only select unique videos using the entry with the highest views.

# %%
yt_clean = youtube_data.groupby('video_id').max()

# %%
yt_clean = yt_clean.sort_values('views', ascending = False)
yt_clean.head(30)
# Out:
#                                                          title trending_date  \
# video_id
# VYOjWnS4cMY  Childish Gambino - This Is America (Official V...      18.31.05
# FlsCjmMhFmw  YouTube Rewind: The Shape of 2017 | #YouTubeRe...      17.14.12
# ffxKSjUwKdU               Ariana Grande - No Tears Left To Cry      18.30.04
# zEf423kYfqk  Becky G, Natti Natasha - Sin Pijama (Official ...      18.30.04
# 7C2z4GqqS5E                BTS (방탄소년단) 'FAKE LOVE' Official MV      18.31.05
# M4ZoCHID9GI     The Weeknd - Call Out My Name (Official Video)      18.30.04
# TyHvyGVs42U          Luis Fonsi, Demi Lovato - Échame La Culpa      17.26.11
# xTlNMmZKwpA  Cardi B, Bad Bunny & J Balvin - I Like It [Off...      18.31.05
# 6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...      17.30.11
# -BQJo3vK8O8              Maluma - El Préstamo (Official Video)      18.25.03
# dfnCAmr569k   45141770  1844959    102849
# J-dv_DcDD_A   44782227  1320316     33742
# 2Vv-BfVoq4g   43449654  1788960     24548
# yDiXQl7grPQ   42799458   564804     33554
# oWw1BcFhk-k   42390420   554509     18381

# %% [markdown]
# We are almost done working with our data! One last bonus challenge is to change the date format to an easier format.

# %% [markdown]
# Convert the "trending_date" column to a pandas-friendly format:

# %%
yt_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6351 entries, VYOjWnS4cMY to y6KYFcta4SE
# Data columns (total 5 columns):
# title            6351 non-null object
# trending_date    6351 non-null object
# views            6351 non-null int64
# likes            6351 non-null int64
# dislikes         6351 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 297.7+ KB

# %%
from datetime import datetime

# %%
yt_clean['trending_date'] = pd.to_datetime(yt_clean['trending_date'], format = '%y.%d.%m')

# %% [markdown]
# ## Example Conclusions from this Workshop

# %% [markdown]
# Here are our top 10 most popular YouTube videos from November 2017 to June 2018.

# %%
yt_clean.head(10)
# Out:
#                                                          title trending_date  \
# video_id
# VYOjWnS4cMY  Childish Gambino - This Is America (Official V...    2018-05-31
# FlsCjmMhFmw  YouTube Rewind: The Shape of 2017 | #YouTubeRe...    2017-12-14
# ffxKSjUwKdU               Ariana Grande - No Tears Left To Cry    2018-04-30
# zEf423kYfqk  Becky G, Natti Natasha - Sin Pijama (Official ...    2018-04-30
# 7C2z4GqqS5E                BTS (방탄소년단) 'FAKE LOVE' Official MV    2018-05-31
# M4ZoCHID9GI     The Weeknd - Call Out My Name (Official Video)    2018-04-30
# TyHvyGVs42U          Luis Fonsi, Demi Lovato - Échame La Culpa    2017-11-26
# xTlNMmZKwpA  Cardi B, Bad Bunny & J Balvin - I Like It [Off...    2018-05-31
# 6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...    2017-11-30
# -BQJo3vK8O8              Maluma - El Préstamo (Official Video)    2018-03-25
#
#                  views    likes  dislikes
# video_id
# VYOjWnS4cMY  225211923  5023450    343541
# FlsCjmMhFmw  149376127  3093544   1643059
# ffxKSjUwKdU  148689896  3094021    129502
# zEf423kYfqk  139334502  1425496    119798
# 7C2z4GqqS5E  123010920  5613827    206892
# M4ZoCHID9GI  122544931  1427436     40837
# TyHvyGVs42U  102012605  2376636    117196
# xTlNMmZKwpA   94254507  1816753    102474
# 6ZfuNTqbHE8   91933007  2625661     53709
# -BQJo3vK8O8   87264467   815369     71494

# %% [markdown]
# Here is the earliest date entry we have for this dataset.

# %%
yt_clean.sort_values('trending_date').head(1)
# Out:
#                                                    title trending_date  views  \
# video_id
# B4gXsobd_ao  What Are Diminutives – and Why We Like Them    2017-11-14  79306
#
#              likes  dislikes
# video_id
# B4gXsobd_ao   3809       127

# %% [markdown]
# Here are the latest dates we have for this data set.

# %%
yt_clean.groupby('trending_date').max().tail(30)
# Out:
#                                                            title      views  \
# trending_date
# 2018-05-15                     WEIRD PRODUCTS | Tati Approved???   15960127
